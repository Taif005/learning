# %%
name = "S. M. Taif Chowdhury"
student_id = 2024360250
cgpa = 3.50

if isinstance(cgpa, float):
    print("True")

print(id(student_id))

mod = student_id % 5
print(mod**3)

print("Hello %s" %name , "Yout student id is %d" %student_id, "and your current CGPA is %.2f" %cgpa)
# Out:
# True
# 1653114734832
# 0
# Hello S. M. Taif Chowdhury Yout student id is 2024360250 and your current CGPA is 3.50

# %%
university_text = "East West University CSE303"
print(len(university_text))
print(university_text.index("W"))
print(university_text[21:27])
print(university_text[0:27:2])
print(university_text[::-1])
split_text = university_text.split(" ")
print(split_text)
# Out:
# 27
# 5
# CSE303
# Es etUiest S33
# 303ESC ytisrevinU tseW tsaE
# ['East', 'West', 'University', 'CSE303']

# %%
ewu_courses= []
ewu_courses.append("CSE101")
ewu_courses.append("CSE102")
ewu_courses.append("CSE207")
ewu_courses.append("CSE303")

print(ewu_courses)
print(ewu_courses[1:3])

for i in ewu_courses:
    print(i)

current_courses = "CSE303"
if current_courses in ewu_courses and :
# Out:
# ['CSE101', 'CSE102', 'CSE207', 'CSE303']
# ['CSE102', 'CSE207']
# CSE101
# CSE102
# CSE207
# CSE303

# %%
course_info = [4, "CSE303" , 2.4]
print("A tuple can contain different types of variables. But whmn we want to assign an element n tuple using append it won't return any element as append assigns elements of same type of variables in the end of a tuple or list")
# Out:
# A tuple can contain different types of variables. But whmn we want to assign an element n tuple using append it won't return any element as append assigns elements of same type of variables in the end of a tuple or list

# %%
x = [1,2,3]
y = [1,2,3]

if x is y:
    print("Same object")
else: 
    print("Different objects")
# Out:
# Different objects
